# %%
import librosa
import numpy as np
import joblib


model = joblib.load("svm_genre_model.pkl")
scaler = joblib.load("scaler.pkl")

genres = ['blues','classical','country','disco','hiphop',
           'jazz','metal','pop','reggae','rock']


def extract_features(file_path):
    y, sr = librosa.load(file_path, duration=30)
    
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    chroma = librosa.feature.chroma_stft(y=y, sr=sr)
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    spectral_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    rms = librosa.feature.rms(y=y)
    mel = librosa.feature.melspectrogram(y=y, sr=sr)
    mel_db = librosa.power_to_db(mel, ref=np.max)
    tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
    
    features = np.hstack([
        np.mean(mfcc, axis=1),
        np.std(mfcc, axis=1),
        np.mean(chroma, axis=1),
        np.mean(spectral_centroid, axis=1),
        np.mean(spectral_bw, axis=1),
        np.mean(rolloff, axis=1),
        np.mean(zcr, axis=1),
        np.mean(rms, axis=1),
        np.mean(mel_db, axis=1),
        np.std(mel_db, axis=1),
        tempo
    ])
    return features

# Prediction function

def predict_genre(file_path):
    print(f"🎵 Analyzing: {file_path}")
    features = extract_features(file_path)
    features_scaled = scaler.transform([features])
    prediction = model.predict(features_scaled)
    predicted_genre = genres[prediction[0]]
    print(f"Predicted Genre: {predicted_genre}")
    return predicted_genre

# %%
# Example usage


predict_genre("C:/Users/neelj/OneDrive/Desktop/ML/archive/Data/dua.wav")
# Out:
# 🎵 Analyzing: C:/Users/neelj/OneDrive/Desktop/ML/archive/Data/dua.wav
# C:\Users\neelj\AppData\Local\Temp\ipykernel_3780\3977786913.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file_path, duration=30)
# C:\ProgramData\anaconda3\envs\genre-classification\lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ✅ Predicted Genre: reggae
# 'reggae'

# %%
predict_genre("C:/Users/neelj/OneDrive/Desktop/ML/archive/Data/daddy2.wav")
# Out:
# 🎵 Analyzing: C:/Users/neelj/OneDrive/Desktop/ML/archive/Data/daddy2.wav
# ✅ Predicted Genre: disco
# 'disco'

# %%
predict_genre("C:/Users/neelj/OneDrive/Desktop/ML/archive/Data/kenny.wav")
# Out:
# 🎵 Analyzing: C:/Users/neelj/OneDrive/Desktop/ML/archive/Data/kenny.wav
# ✅ Predicted Genre: country
# 'country'

# %%
predict_genre("C:/Users/neelj/OneDrive/Desktop/ML/archive/Data/fred.wav")
# Out:
# 🎵 Analyzing: C:/Users/neelj/OneDrive/Desktop/ML/archive/Data/fred.wav
# ✅ Predicted Genre: hiphop
# 'hiphop'
